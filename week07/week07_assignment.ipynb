# %% [markdown]
# # Week 7 Assignment
#
# This week has been all about getting information off the internet both in structured data formats (CSV, JSON, etc) as well as HTML.  Answer the questions below as instructed.

# %% [markdown]
# ### 31.1 Finding files on the internet
#
# Go to healthdata.gov and find a file that looks interesting to you.  Provide the metadata below that describes the file you located.
#
# The cell below is a "markdown" cell.  Just double-click it to edit the contents and then Shift-Enter to show the content as formatted text.
#
# ---

# %% [markdown]
# **File Name:** NNDSS_-_TABLE_1FF._Severe_acute_respiratory_syndrome-associated_coronavirus_disease_to_Shigellosis
#
# **URL to Page:** https://healthdata.gov/dataset/nndss-table-1ff-severe-acute-respiratory-syndrome-associated-coronavirus-disease-9
#
# **Description:** This table contains provisional cases of national notifiable diseases from the National Notifiable Diseases Surveillance System (NNDSS). It is about severe acute respiratory syndrome-associated coronavirus disease and Shigellosis data from the 50 states. I am interested in this data because of the current outbreak of coronavirus.
#
# **URL to Actual File:** https://healthdata.gov/dataset/nndss-table-1ff-severe-acute-respiratory-syndrome-associated-coronavirus-disease-10#{view-graph:{graphOptions:{hooks:{processOffset:{},bindEvents:{}}}},graphOptions:{hooks:{processOffset:{},bindEvents:{}}}}
#
# **File Format:** CSV

# %% [markdown]
# ---

# %% [markdown]
# ### 31.2 Use Pandas to load data from internet
#
# Now write a block of code (doesn't need to be in a function) that will load the file using Pandas and describe the shape of the file contents.  I've provided a cell with some comments in it to help get you started.
#
# Pandas documentation for loading data https://pandas.pydata.org/pandas-docs/version/0.23.4/api.html#input-output
#
# Pandas documentation for describing the shape of data https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.shape.html

# %%
import pandas as pd
df = pd.read_csv('NNDSS_-_TABLE_1FF._Severe_acute_respiratory_syndrome-associated_coronavirus_disease_to_Shigellosis.csv')
df.head()

# Load data using one of the read functions depending on your data file type
# data = pd.read_ ...

# Print out the row / column count
# data. ...
# Out:
#        Reporting Area  MMWR Year  MMWR Week  \
# 0               TOTAL       2020          1
# 1        US RESIDENTS       2020          2
# 2      US TERRITORIES       2020          1
# 3  WEST SOUTH CENTRAL       2020          1
# 4            ILLINOIS       2020          1
#
#    Severe acute respiratory syndrome-associated coronavirus desease, Current week  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Severe acute respiratory syndrome-associated coronavirus desease, Current week, flag  \
# 0                                                  -
# 1                                                  -
# 2                                                  -
# 3                                                  -
# 4                                                  -
#
#    Severe acute respiratory syndrome-associated coronavirus desease, Previous 52 weeks Max†  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Severe acute respiratory syndrome-associated coronavirus desease, Previous 52 weeks Max†, flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Severe acute respiratory syndrome-associated coronavirus desease, Cum 2020†  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Severe acute respiratory syndrome-associated coronavirus desease, Cum 2020†, flag  \
# 0                                                  -
# 1                                                  -
# 2                                                  -
# 3                                                  -
# 4                                                  -
#
#    Severe acute respiratory syndrome-associated coronavirus desease, Cum 2019†  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ... Shigellosis, Previous 52 weeks Max†  \
# 0  ...                                 770
# 1  ...                                 458
# 2  ...                                   0
# 3  ...                                 182
# 4  ...                                  16
#
#    Shigellosis, Previous 52 weeks Max†, flag Shigellosis, Cum 2020†  \
# 0                                        NaN                   55.0
# 1                                        NaN                  154.0
# 2                                        NaN                    NaN
# 3                                        NaN                    5.0
# 4                                        NaN                    NaN
#
#    Shigellosis, Cum 2020†, flag  Shigellosis, Cum 2019†  \
# 0                           NaN                   197.0
# 1                           NaN                   501.0
# 2                             -                     NaN
# 3                           NaN                     4.0
# 4                             -                    11.0
#
#    Shigellosis, Cum 2019†, flag Location 1          Location 2  \
# 0                           NaN        NaN               TOTAL
# 1                           NaN        NaN        US RESIDENTS
# 2                             -        NaN      US TERRITORIES
# 3                           NaN        NaN  WEST SOUTH CENTRAL
# 4                           NaN   ILLINOIS                 NaN
#
#   Reporting Area Sort      New Georeferenced Column
# 0            20200170                           NaN
# 1            20200201                           NaN
# 2            20200163                           NaN
# 3            20200143                           NaN
# 4            20200115  POINT (-89.148632 40.124144)
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (490, 31)

# %% [markdown]
# ---

# %% [markdown]
# ### 32.1 HTML Basics
#
# HTML is a form of which othere data format we've talked about:
#
# > A) Binary
# >
# > B) eXtensible Markup Language
# >
# > C) JavaScript Object Notation
# >
# > D) HL7 FHIR

# %%
answer321 = "B"

# %% [markdown]
# ### 32.2 Things in HTML
#
# Which of the following is **not** a part of HTML:
#
# > A) element
# >
# > B) tag
# >
# > C) dictionary
# >
# > D) attribute

# %%
answer322 = "C"

# %% [markdown]
# ### 32.3 Parsing HTML in Python
#
# Which of the following packages can be used to extract a table of data from HTML using Python (include all that apply in a list):
#
# > A) lxml
# >
# > B) BeautifulSoup
# >
# > C) Pandas
# >
# > D) fuzzywuzzy

# %%
answer323 = ["A","B","C"]
